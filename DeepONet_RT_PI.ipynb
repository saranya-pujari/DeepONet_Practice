# %% [markdown]
# <a href="https://colab.research.google.com/github/saranya-pujari/DeepONet_Practice/blob/main/DeepONet_RT_PI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepONet - Diffusion Reaction (No PI)

# %%
import jax
import jax.numpy as np
from jax import random, grad, vmap, jit, hessian, lax
from jax.example_libraries import optimizers
from jax.nn import relu
from jax.flatten_util import ravel_pytree

import itertools
from functools import partial
from torch.utils import data
from tqdm import trange, tqdm
import matplotlib.pyplot as plt

from scipy.interpolate import griddata
# %matplotlib inline

# %% [markdown]
# ## Neural network and model creation (think DeepONet_model)

# %%
# Define the neural net
def MLP(layers, activation=relu):
  ''' Vanilla MLP'''
  def init(rng_key):
      def init_layer(key, d_in, d_out):
          k1, k2 = random.split(key)
          glorot_stddev = 1. / np.sqrt((d_in + d_out) / 2.)
          W = glorot_stddev * random.normal(k1, (d_in, d_out))
          b = np.zeros(d_out)
          return W, b
      key, *keys = random.split(rng_key, len(layers))
      params = list(map(init_layer, keys, layers[:-1], layers[1:]))
      return params
  def apply(params, inputs):
      for W, b in params[:-1]:
          outputs = np.dot(inputs, W) + b
          inputs = activation(outputs)
      W, b = params[-1]
      outputs = np.dot(inputs, W) + b
      return outputs
  return init, apply

# %%
# Define the model
class DeepONet:
    def __init__(self, branch_layers, trunk_layers):
        # Network initialization and evaluation functions
        self.branch_init, self.branch_apply = MLP(branch_layers, activation=np.tanh)  # or Relu
        self.trunk_init, self.trunk_apply = MLP(trunk_layers, activation=np.tanh)     # or Relu

        # Initialize
        branch_params = self.branch_init(rng_key = random.PRNGKey(1234))
        trunk_params = self.trunk_init(rng_key = random.PRNGKey(4321))
        params = (branch_params, trunk_params)

        # Use optimizers to set optimizer initialization and update functions
        self.opt_init, \
        self.opt_update, \
        self.get_params = optimizers.adam(optimizers.exponential_decay(1e-3,
                                                                      decay_steps=2000,
                                                                      decay_rate=0.9))
        self.opt_state = self.opt_init(params)

        # Used to restore the trained model parameters
        _, self.unravel_params = ravel_pytree(params)

        self.itercount = itertools.count()

        # Loggers
        self.loss_log = []
        #self.loss_bcs_log = []
        #self.loss_res_log = []

    # Define DeepONet architecture
    def operator_net(self, params, u, x, t):
        branch_params, trunk_params = params
        y = np.stack([x, t])
        B = self.branch_apply(branch_params, u)
        T = self.trunk_apply(trunk_params, y)
        outputs = np.sum(B * T)
        return  outputs

    # Define operator loss
    def loss_operator(self, params, batch):
        inputs, outputs = batch
        u, y = inputs
        # Compute forward pass
        s_pred = vmap(self.operator_net, (None, 0, 0, 0))(params, u, y[:,0], y[:,1])
        # Compute loss
        loss = np.mean((outputs.flatten() - s_pred.flatten())**2)
        return loss

    # Define a compiled update step
    @partial(jit, static_argnums=(0,))
    def step(self, i, opt_state, batch):
        params = self.get_params(opt_state)
        g = grad(self.loss_operator)(params, batch)
        return self.opt_update(i, g, opt_state)

    # Optimize parameters in a loop
    def train(self, dataset, nIter = 10000):
        # Define data iterators
        data_iterator = iter(dataset)

        pbar = trange(nIter)
        # Main training loop
        for it in pbar:
            # Fetch data
            batch = next(data_iterator)

            self.opt_state = self.step(next(self.itercount), self.opt_state, batch)

            if it % 100 == 0:
                params = self.get_params(self.opt_state)

                # Compute loss
                loss_value = self.loss_operator(params, batch)

                # Store loss
                self.loss_log.append(loss_value)

                # Print loss
                pbar.set_postfix({'Loss': loss_value})

    # Evaluates predictions at test points
    @partial(jit, static_argnums=(0,))
    def predict_s(self, params, U_star, Y_star):
        s_pred = vmap(self.operator_net, (None, 0, 0, 0))(params, U_star, Y_star[:,0], Y_star[:,1])
        return s_pred

# %% [markdown]
# ## Dataset generation & PDE solver

# %%
# Data generator
class DataGenerator(data.Dataset):
    def __init__(self, u, y, s,
                 batch_size=64, rng_key=random.PRNGKey(1234)):
        'Initialization'
        self.u = u # input sample
        self.y = y # location
        self.s = s # labeled data evulated at y (solution measurements, BC/IC conditions, etc.)

        self.N = u.shape[0]
        self.batch_size = batch_size
        self.key = rng_key

    def __getitem__(self, index):
        'Generate one batch of data'
        self.key, subkey = random.split(self.key)
        inputs, outputs = self.__data_generation(subkey)
        return inputs, outputs

    @partial(jit, static_argnums=(0,))
    def __data_generation(self, key):
        'Generates data containing batch_size samples'
        idx = random.choice(key, self.N, (self.batch_size,), replace=False)
        s = self.s[idx,:]
        y = self.y[idx,:]
        u = self.u[idx,:]
        # Construct batch
        inputs = (u, y)
        outputs = s
        return inputs, outputs

# %% [markdown]
# PDE Solver

# %%
def quadrature(I, src_prev, src_curr, src_next, dtau_prev, dtau_next):
    # 1st order quadrature
    xp = np.exp(-dtau_prev)
    u = 0.5 * (1 - xp)
    v = 0.5 * (1 - xp)
    w = 0.0
    I_new = I * xp + u * src_prev + v * src_curr + w * src_next
    return I_new, u, v, w

def quadrature3(I, src_prev, src_curr, src_next, dtau_prev, dtau_next):
    xp = np.exp(-dtau_prev) # Precalculate e^(-delta Tau)
    e0 = 1 - xp
    e1 = dtau_prev - e0
    e2 = dtau_prev**2 - 2 * e1
    u = e0 + (e2 - (2 * dtau_prev + dtau_next) * e1) / (dtau_prev * (dtau_prev+dtau_next))
    v  = ((dtau_prev + dtau_next) * e1 - e2) / (dtau_prev * dtau_next)
    w  = (e2 - dtau_prev * e1) / (dtau_next * (dtau_prev + dtau_next))
    I_new = I * xp + u * src_prev + v * src_curr + w * src_next
    return I_new, u, v, w

def ng_accel(sppprev, spprev, sprev, scur, eps=1e-10):
    q1 = scur - 2 * sprev + spprev
    q2 = scur - sprev - spprev + sppprev
    q3 = scur - sprev

    a1 = np.dot(q1, q1)
    b1 = np.dot(q1, q2)
    c1 = np.dot(q1, q3)
    a2 = np.dot(q2, q1)
    b2 = np.dot(q2, q2)
    c2 = np.dot(q2, q3)

    denom = a1 * b2 - a2 * b1

    def no_accel_fn(_):
        return scur

    def accel_fn(_):
        a = (c1 * b2 - c2 * b1) / denom
        b = (c2 * a1 - c1 * a2) / denom
        return (1 - a - b) * scur + a * sprev + b * spprev

    return lax.cond(np.abs(denom) < eps, no_accel_fn, accel_fn, operand=None)

def tridiag(a, b, c, r):
    n = len(a)
    u = np.zeros(n, dtype=float)
    gamma = np.zeros(n, dtype=float)

    beta = lax.cond(
        b[0] == 0.0,
        lambda _: np.nan,
        lambda _: b[0],
        operand=None
    )
    u = u.at[0].set(r[0] / beta)

    for j in range(1, n):
        gamma = gamma.at[j].set(c[j - 1] / beta)
        beta = b[j] - a[j] * gamma[j]
        beta = lax.cond(
            beta == 0.0,
            lambda _: np.nan,
            lambda _: beta,
            operand=None
        )
        u = u.at[j].set((r[j] - a[j] * u[j - 1]) / beta)

    for j in range(n - 2, 0, -1):
        u = u.at[j].set(u[j] - gamma[j + 1] * u[j + 1])

    return u


def lambda_iteration(alpha, eps, n_iter, Nz, use_tridiag=False, ng=False):
    nzi = Nz + 1
    nzc = Nz
    mu = 1.0 / np.sqrt(3.0)

    # Optical depth grid
    zi = np.linspace(0, 1, nzi)
    zc = 0.5 * (zi[:-1] + zi[1:])
    dz = np.diff(zi)

    bnu = np.ones(nzi)
    dtau = alpha * dz / mu

    dtaui = np.zeros(nzi)
    dtaui = dtaui.at[1:-1].set(0.5 * (dtau[1:] + dtau[:-1]))
    dtaui = dtaui.at[0].set(2 * dtaui[1] - dtaui[2])
    dtaui = dtaui.at[-1].set(2 * dtaui[-2] - dtaui[-3])

    # Source Function
    dmt_a   = np.zeros(nzi)
    dmt_b   = np.ones(nzi)
    dmt_c   = np.zeros(nzi)
    drs     = np.ones(nzi)

    for i in range (1, nzi - 1):
        dmt_a = dmt_a.at[i].set(-1.0 / (dtaui[i] * dtau[i - 1]))
        dmt_b = dmt_b.at[i].set(eps + 1.0 / (dtaui[i] * dtau[i - 1]) + 1.0 / (dtaui[i] * dtau[i]))
        dmt_c = dmt_c.at[i].set(-1.0 / (dtaui[i] * dtau[i]))
        drs = drs.at[i].set(eps * bnu[i])

    dmt_a = dmt_a.at[0].set(0)
    dmt_b = dmt_b.at[0].set(1)
    dmt_c = dmt_c.at[0].set(0)
    drs = drs.at[0].set(bnu[0])

    dmt_a = dmt_a.at[-1].set(-1.0 / dtau[-1])
    dmt_b = dmt_b.at[-1].set(1.0 / dtau[-1] + 1.0)
    dmt_c = dmt_c.at[-1].set(0.0)
    drs   = drs.at[-1].set(0.0)

    j_diff = tridiag(dmt_a, dmt_b, dmt_c, drs)
    s_diff = eps * bnu + (1 - eps) * j_diff
    s_diff = s_diff[:-1]
    return s_diff

# %% [markdown]
# Sample generation

# %%
def alpha(alpha0, alpha1, Nz):
    zi = np.linspace(0, 1, Nz + 1)
    zc = 0.5 * (zi[:-1] + zi[1:])
    return np.exp(np.log(alpha0) + (np.log(alpha1) - np.log(alpha0)) * zc)

# A radiative transfer numerical solver
def solve_RTE(key, Nz, P, eps):
    # Split key into subkeys for each random draw
    key_eps, key_a0, key_a1, key_idx = random.split(key, 4)

    if eps == None:
      exp = random.uniform(key_eps, shape=(), minval=-4, maxval=-1)
      eps = 10 ** exp
      # eps = random.uniform(key_eps, shape=(), minval=1e-4, maxval=0.5)
    alpha0 = 1e5
    alpha1 = 1e-1

    zi = np.linspace(0, 1, Nz + 1)
    zc = 0.5 * (zi[:-1] + zi[1:])
    alpha_z = alpha(alpha0, alpha1, Nz)

    s_z = lambda_iteration(alpha_z, eps, 50, Nz)

    idx = random.choice(key_idx, Nz, shape=(P,), replace=False)
    y = zc[idx][:, None]
    s = s_z[idx]
    u = alpha_z
    return (zc, s_z), (u, y, s), eps

# Generate training data corresponding to one input sample
def generate_one_training_data(key, P):
    (z, s_z), (u, y, s), eps = solve_RTE(key, Nz, P, eps=None)
    u = np.tile(u, (P, 1))
    return u, y, s, eps

# Generate training data corresponding to N input sample
def generate_training_data(key, N, P):
    jax.config.update("jax_enable_x64", True)
    keys = random.split(key, N)
    u_train, y_train, s_train, eps_train = vmap(generate_one_training_data, (0, None))(keys, P)

    u_train = np.float32(u_train.reshape(N * P, -1))
    y_train = np.float32(y_train.reshape(N * P, -1))
    s_train = np.float32(s_train.reshape(N * P, -1))
    eps_train = np.float32(eps_train.reshape(N, -1))
    jax.config.update("jax_enable_x64", False)

    return u_train, y_train, s_train, eps_train

# Generate test data corresponding to one input sample
def generate_one_test_data(key, P, eps):
    (z, s_z), (u, y, s), eps = solve_RTE(key, Nz, P, eps)
    ZZ = np.meshgrid(z)[0].flatten()[:, None]
    u_test = np.tile(u, (P, 1))
    print("u_test shape:", u_test.shape)
    y_test = ZZ
    print("y_test shape:", y_test.shape)
    s_test = s_z
    print("s_test shape:", s_test.shape)
    return u_test, y_test, s_test

def generate_test_data(key, N, P, eps):
    jax.config.update("jax_enable_x64", True)
    keys = random.split(key, N)
    u_test, y_test, s_test = vmap(generate_one_test_data, (0, None, None))(keys, P, eps)
    print("u_test shape:", u_test.shape)
    print("y_test shape:", y_test.shape)
    print("s_test shape:", s_test.shape)

    u_test = np.float32(u_test.reshape(N * P, -1))
    y_test = np.float32(y_test.reshape(N * P, -1))
    s_test = np.float32(s_test.reshape(N * P, -1))
    jax.config.update("jax_enable_x64", False)
    return u_test, y_test, s_test

# Compute relative l2 error over N test samples.
def compute_error(key, P, eps):
    # Generate one test sample
    u_test, y_test, s_test = generate_test_data(key, 1, P, eps)
    # Predict
    s_pred = model.predict_s(params, u_test, y_test)[:,None]
    # Compute relative l2 error
    error_s = np.linalg.norm(s_test - s_pred) / np.linalg.norm(s_test)
    return error_s

# %% [markdown]
# ## Set up dataset & model parameters

# %%
key = random.PRNGKey(0)

# Resolution of the solution
Nz = 100
N = 5000 # number of input samples
m = Nz   # number of input sensors
P_train = 100 # number of output sensors

u_train, y_train, s_train, eps_train = generate_training_data(key, N, P_train)
print('u_train shape: {}'.format(u_train.shape))
print('y_train shape: {}'.format(y_train.shape))
print('s_train shape: {}'.format(s_train.shape))
# Out:
# u_train shape: (500000, 100)
# y_train shape: (500000, 1)
# s_train shape: (500000, 1)

# %%
eps_log = np.log10(eps_train)
plt.figure(figsize=(6,4))
plt.hist(eps_log, bins=100, density=True, alpha=0.7)
plt.xlabel("log(epsilon)")
plt.ylabel("Density")
plt.title("Distribution of Sampled epsilons")
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.show()

# %%
# Initialize model
branch_layers = [m, 50, 50, 50, 50, 50]
trunk_layers =  [2, 50, 50, 50, 50, 50]
model = DeepONet(branch_layers, trunk_layers)

# %%
# Create data set
batch_size = 10000
dataset = DataGenerator(u_train, y_train, s_train, batch_size)

# %% [markdown]
# ## Run model

# %%
# Train
model.train(dataset, nIter=240000)
# Out:
# 100%|██████████| 240000/240000 [09:34<00:00, 418.01it/s, Loss=0.02009158]

# %% [markdown]
# ## Testing & Visualization

# %%
# Test data
N_test =100 # number of input samples
P_test = Nz   # number of sensors
key_test = random.PRNGKey(1234567)
keys_test = random.split(key_test, N_test)

# Predict
params = model.get_params(model.opt_state)

# Compute error
error_s = vmap(compute_error, (0, None, None))(keys_test,P_test,None)

print('mean of relative L2 error of s: {:.2e}'.format(error_s.mean()))
print('std of relative L2 error of s: {:.2e}'.format(error_s.std()))
# Out:
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
# mean of relative L2 error of s: 1.80e-01
# std of relative L2 error of s: 8.66e-02

# %%
#Plot for loss function
plt.figure(figsize = (6,5))
plt.plot(model.loss_log, lw=2)

plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.yscale('log')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1635111999.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Generate one test sample
key = random.PRNGKey(12345)
P_test = 100
Nx = m
u_test, y_test, s_test = generate_test_data(key, 1, P_test, None)

# Predict
params = model.get_params(model.opt_state)
s_pred = model.predict_s(params, u_test, y_test)

# Generate an uniform mesh
z = np.linspace(0, 1, Nz)
ZZ = np.meshgrid(z)[0].flatten()[:, None]

# Grid data
S_pred = griddata(y_test, s_pred.flatten(), (ZZ), method='cubic')
S_test = griddata(y_test, s_test.flatten(), (ZZ), method='cubic')

# Compute the relative l2 error
error = np.linalg.norm(S_pred - S_test, 2) / np.linalg.norm(S_test, 2)
print('Relative l2 error: {:.3e}'.format(error))
# Out:
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
# Relative l2 error: nan

# %%
key = random.PRNGKey(123)
P_test = 100
N_test = 1
Nz = 100
m = Nz

u_test, y_test, s_test = generate_test_data(key, N_test, P_test, None)

# Predict
params = model.get_params(model.opt_state)
s_pred = model.predict_s(params, u_test, y_test)

# Create uniform mesh on [0,1] with Nz points
z_uniform = np.linspace(0, 1, Nz)
ZZ = z_uniform[:, None]

# Grid data
S_pred = griddata(y_test, s_pred.flatten(), ZZ, method='cubic')
S_test = griddata(y_test, s_test.flatten(), ZZ, method='cubic')

# Clean up any NaNs from interpolation
mask = ~np.isnan(S_pred) & ~np.isnan(S_test)
S_pred = S_pred[mask]
S_test = S_test[mask]

# --- Compute relative L2 error ---
error = np.linalg.norm(S_pred - S_test, 2) / np.linalg.norm(S_test, 2)
print('Relative L2 error: {:.3e}'.format(error))
# Out:
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
# Relative L2 error: 8.862e-02

# %%
# Plot
fig, axs = plt.subplots(1, 3, figsize=(18, 5))
ZZ = ZZ[1:-1]

# 1. Ground truth
axs[0].plot(ZZ, S_test, label='True', color='blue')
axs[0].set_title('Exact $s(z)$')
axs[0].set_xlabel('$z$')
axs[0].set_ylabel('$s$')
axs[0].grid(True)

# 2. Prediction
axs[1].plot(ZZ, S_pred, label='Predicted', color='red')
axs[1].set_title('Predicted $s(z)$')
axs[1].set_xlabel('$z$')
axs[1].set_ylabel('$s$')
axs[1].grid(True)

# 3. Absolute error
axs[2].plot(ZZ, np.abs(S_pred - S_test), label='|Error|', color='black')
axs[2].set_title('Absolute Error $|s_{\mathrm{pred}} - s_{\mathrm{true}}|$')
axs[2].set_xlabel('$z$')
axs[2].set_ylabel('Error')
axs[2].grid(True)

plt.tight_layout()
plt.show()
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# <>:21: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-1850483802.py:21: SyntaxWarning: invalid escape sequence '\m'
#   axs[2].set_title('Absolute Error $|s_{\mathrm{pred}} - s_{\mathrm{true}}|$')

# %%
def visualize(eps):
    key = random.PRNGKey(123)
    P_test = 100
    N_test = 1
    Nz = 100
    m = Nz

    u_test, y_test, s_test = generate_test_data(key, N_test, P_test, eps)

    # Predict
    params = model.get_params(model.opt_state)
    s_pred = model.predict_s(params, u_test, y_test)

    # Create uniform mesh on [0,1] with Nz points
    z_uniform = np.linspace(0, 1, Nz)
    ZZ = z_uniform[:, None]

    # Grid data (interpolated onto ZZ)
    S_pred = griddata(y_test, s_pred.flatten(), ZZ, method='cubic')
    S_test = griddata(y_test, s_test.flatten(), ZZ, method='cubic')

    # Clean up any NaNs from interpolation
    mask = ~np.isnan(S_pred) & ~np.isnan(S_test)
    ZZ = ZZ[mask].flatten()
    S_pred = S_pred[mask]
    S_test = S_test[mask]

    # --- Compute relative L2 error ---
    error = np.linalg.norm(S_pred - S_test, 2) / np.linalg.norm(S_test, 2)
    print('Relative L2 error: {:.3e}'.format(error))

    # Plot
    fig, axs = plt.subplots(1, 2, figsize=(14, 5))

    # 1. Exact vs Predicted
    axs[0].plot(ZZ, S_test, label='Exact', color='blue', linewidth=2)
    axs[0].plot(ZZ, S_pred, label='Predicted', color='red', linewidth=2)
    axs[0].set_title(f"$s(z)$, Epsilon = {eps}", fontsize=18)
    axs[0].set_xlabel('$z$', fontsize=16)
    axs[0].set_ylabel('$s$', fontsize=16)
    axs[0].legend(fontsize=12)
    axs[0].grid(True)

    # 2. Absolute error
    axs[1].plot(ZZ, np.abs(S_pred - S_test), label='|Error|', color='black')
    axs[1].set_title('Absolute Error $|s_{pred} - s_{true}|$', fontsize=18)
    axs[1].set_xlabel('$z$', fontsize=16)
    axs[1].set_ylabel('Error', fontsize=16)
    axs[1].grid(True)

    plt.tight_layout()
    plt.show()

# %%
def get_S(eps):
    key = random.PRNGKey(123)
    P_test = 100
    N_test = 1
    Nz = 100
    m = Nz

    u_test, y_test, s_test = generate_test_data(key, N_test, P_test, eps)

    # Predict
    params = model.get_params(model.opt_state)
    s_pred = model.predict_s(params, u_test, y_test)

    # Create uniform mesh on [0,1] with Nz points
    z_uniform = np.linspace(0, 1, Nz)
    ZZ = z_uniform[:, None]

    # Grid data (interpolated onto ZZ)
    S_pred = griddata(y_test, s_pred.flatten(), ZZ, method='cubic')
    S_test = griddata(y_test, s_test.flatten(), ZZ, method='cubic')

    # Clean up any NaNs from interpolation
    mask = ~np.isnan(S_pred) & ~np.isnan(S_test)
    ZZ = ZZ[mask].flatten()
    S_pred = S_pred[mask]
    S_test = S_test[mask]
    abs_error = np.abs(S_pred - S_test)
    l2_error = np.linalg.norm(S_pred - S_test, 2) / np.linalg.norm(S_test, 2)

    return ZZ, S_pred, S_test, abs_error, l2_error


def visualize_all():
    # Gather data to be plotted
    draws = [0.1, 0.01, 0.001, 0.0001]
    fig, axs = plt.subplots(len(draws), 2, figsize=(14, 4*len(draws)))

    for i, eps in enumerate(draws):
        # Compute predictions and errors
        ZZ, S_pred, S_test, abs_error, l2_error = get_S(eps)

        # --- Left column: Exact vs Predicted ---
        axs[i, 0].plot(ZZ, S_test, label='Exact', color='blue', linewidth=2)
        axs[i, 0].plot(ZZ, S_pred, label='Predicted', color='red', linewidth=2)
        axs[i, 0].set_title(f"$s(z)$, ε = {eps}, L2 error={l2_error:.3e}", fontsize=14)
        axs[i, 0].set_xlabel('$z$', fontsize=12)
        axs[i, 0].set_ylabel('$s$', fontsize=12)
        axs[i, 0].legend(fontsize=10)
        axs[i, 0].grid(True)

        # --- Right column: Absolute Error ---
        axs[i, 1].plot(ZZ, abs_error, label='|Error|', color='black')
        axs[i, 1].set_title('Absolute Error $|s_{pred} - s_{true}|$', fontsize=14)
        axs[i, 1].set_xlabel('$z$', fontsize=12)
        axs[i, 1].set_ylabel('Error', fontsize=12)
        axs[i, 1].grid(True)

    plt.tight_layout()
    plt.show()

visualize_all()
# Out:
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
# u_test shape: (100, 100)
# y_test shape: (100, 1)
# s_test shape: (100,)
# u_test shape: (1, 100, 100)
# y_test shape: (1, 100, 1)
# s_test shape: (1, 100)
